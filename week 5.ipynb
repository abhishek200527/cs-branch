# %%
import pandas as pd 
df = pd.read_csv('C:\\Users\\ABHISHEK KUMAR\\Desktop\\Titanic.csv') 
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\\Users\\ABHISHEK KUMAR\\Desktop\\Titanic.csv')
#       3 df.info()
#
# ...

# %%
import pandas as p
df=p.read_csv("C:\\Users\\ABHISHEK KUMAR\\Desktop\\Titanic-Dataset.csv")

info=df.info()

print("\n\n\nis_na:\n\n",df.isna())

is_null_su=df.isna().sum()
print("\n\n\nCount of all Missing values:\n\n",df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
#
#
# is_na:
#
#       PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# ...

# %%
import numpy as n
print(df.isna().sum()) 
#Replacingall NaN values with -1
df=df.replace({n.nan:-1}) 
print("\n\n\n") 
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
#
#
#
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sea
import pandas as pd

a = pd.read_csv("C:\\Users\\ABHISHEK KUMAR\\Desktop\\Titanic-Dataset.csv")
b = sea.boxplot(x=a["Age"])

plt.xlabel("Age")
plt.ylabel("Name")
b.set_title("Age_Box_Plot")
plt.show()

# %%
#extract the upper and lower quantiles
height_lq = df["Age"].quantile(0.75) 
height_uq = df["Age"].quantile(0.75) 
#extract the inter quartile range
height_iqr = height_uq -height_lq
#get the upper and lower bounds
lower_bound=height_lq-1.5*height_iqr
upper_bound=height_uq+1.5*height_iqr
#extract bvalues outside these bounds
height_outliers=df[(df.Age<=lower_bound) | (df.Age>=upper_bound)]
height_outliers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib 
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("C:\\Users\\ABHISHEK KUMAR\\Desktop\\Titanic-Dataset.csv") 
dff=sns.boxplot(x=df['Age'],y=df['Sex'])
dff.set_title('Bivariate Outlier Detection') 
plt.show()

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:\\Users\\ABHISHEK KUMAR\\Downloads\\temp.csv") 
df
import matplotlib.pyplot as plt 
x=df.day
y=df.temp
plt.scatter(x,y,label="values of x&y") 
plt.xlabel('day') 
plt.ylabel('temp') 
plt.title('Scatter plot') 
plt.show()
